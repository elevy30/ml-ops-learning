# %% [markdown]
# ### Quickstart: Compare runs, choose a model, and deploy it to a REST API
#
# In this quickstart, you will:
#
# - Run a hyperparameter sweep on a training script
#
# - Compare the results of the runs in the MLflow UI
#
# - Choose the best run and register it as a model
#
# - Deploy the model to a REST API
#
# - Build a container image suitable for deployment to a cloud platform

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
## load the dataset
data=pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Split the data into training,validation and test sets
train,test=train_test_split(data,test_size=0.25,random_state=42)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
## get the result column - use ravel to convert it to 1D array
train[['quality']].values.ravel()
# Out:
# array([6, 6, 5, ..., 6, 6, 8])

# %%
train_x=train.drop(['quality'],axis=1).values
train_y=train[['quality']].values.ravel()

## test dataset
test_x=test.drop(['quality'],axis=1).values
test_y=test[['quality']].values.ravel()

## splitting this train data into train and validation
train_x,valid_x,train_y,valid_y=train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature=infer_signature(train_x,train_y)

# %%
np.mean(train_x,axis=0)
# Out:
# array([6.86621852e+00, 2.80377808e-01, 3.32597005e-01, 6.42164738e+00,
#        4.55513955e-02, 3.53556841e+01, 1.38792376e+02, 9.94074221e-01,
#        3.18919333e+00, 4.88396869e-01, 1.05005673e+01])

# %%
train_x.shape[1]
# Out:
# 11

# %%
### ANN Model
def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params with MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLFlow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_experiment("wine-quality")
with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# 2025/02/20 18:05:16 INFO mlflow.tracking.fluent: Experiment with name 'wine-quality' does not exist. Creating a new experiment.
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3:09 4s/step - loss: 38.9838 - root_mean_squared_error: 6.2437
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.3251 - root_mean_squared_error: 4.9670
# 19/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.3056 - root_mean_squared_error: 3.7919
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.9252 - root_mean_squared_error: 3.7410
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.4701 - root_mean_squared_error: 3.2430
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 9.3597 - root_mean_squared_error: 2.9003 - val_loss: 0.6979 - val_root_mean_squared_error: 0.8354
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.7059 - root_mean_squared_error: 0.8402
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6551 - root_mean_squared_error: 0.8091
# 27/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6508 - root_mean_squared_error: 0.8066
# 41/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6391 - root_mean_squared_error: 0.7993
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6355 - root_mean_squared_error: 0.7970 - val_loss: 0.5654 - val_root_mean_squared_error: 0.7519
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.7212 - root_mean_squared_error: 0.8492
# 16/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5768 - root_mean_squared_error: 0.7590
# 29/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5724 - root_mean_squared_error: 0.7563
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5737 - root_mean_squared_error: 0.7573
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5727 - root_mean_squared_error: 0.7566 - val_loss: 0.5342 - val_root_mean_squared_error: 0.7309
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.4453 - root_mean_squared_error: 0.6673
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5103 - root_mean_squared_error: 0.7139
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - loss: 34.2234 - root_mean_squared_error: 5.8501
# 22/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.2279 - root_mean_squared_error: 4.4235
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.0255 - root_mean_squared_error: 3.7552
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 13.7910 - root_mean_squared_error: 3.5824 - val_loss: 1.9966 - val_root_mean_squared_error: 1.4130
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 1.3437 - root_mean_squared_error: 1.1592
# 16/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7356 - root_mean_squared_error: 1.3164
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7008 - root_mean_squared_error: 1.3036
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6830 - root_mean_squared_error: 1.2968 - val_loss: 1.5295 - val_root_mean_squared_error: 1.2367
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 1.7088 - root_mean_squared_error: 1.3072
# 17/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3826 - root_mean_squared_error: 1.1749
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3776 - root_mean_squared_error: 1.1732
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3505 - root_mean_squared_error: 1.1616 - val_loss: 1.2630 - val_root_mean_squared_error: 1.1238
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.9968 - root_mean_squared_error: 0.9984
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2449 - root_mean_squared_error: 1.1149
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 42s 938ms/step - loss: 37.3093 - root_mean_squared_error: 6.1081
# 18/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.9196 - root_mean_squared_error: 5.9085
# 35/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.4624 - root_mean_squared_error: 5.7827
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 32.5101 - root_mean_squared_error: 5.6984 - val_loss: 22.2344 - val_root_mean_squared_error: 4.7153
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 19.9436 - root_mean_squared_error: 4.4658
# 21/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.0212 - root_mean_squared_error: 4.5845
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.8929 - root_mean_squared_error: 4.4579
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.6913 - root_mean_squared_error: 4.4347 - val_loss: 13.3010 - val_root_mean_squared_error: 3.6471
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 12.5629 - root_mean_squared_error: 3.5444
# 22/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.5019 - root_mean_squared_error: 3.5352
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.9753 - root_mean_squared_error: 3.4591
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.7890 - root_mean_squared_error: 3.4316 - val_loss: 8.2359 - val_root_mean_squared_error: 2.8698
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 8.4230 - root_mean_squared_error: 2.9022
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2488 - root_mean_squared_error: 2.8720
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 41s 917ms/step - loss: 35.2788 - root_mean_squared_error: 5.9396
# 19/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.0076 - root_mean_squared_error: 5.3760
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 24.0876 - root_mean_squared_error: 4.8766
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 22.7990 - root_mean_squared_error: 4.7353 - val_loss: 4.5525 - val_root_mean_squared_error: 2.1337
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 7s 177ms/step - loss: 5.0359 - root_mean_squared_error: 2.2441
# 17/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3047 - root_mean_squared_error: 2.0714
# 34/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7421 - root_mean_squared_error: 1.9268
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5110 - root_mean_squared_error: 1.8654 - val_loss: 1.9878 - val_root_mean_squared_error: 1.4099
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 2.5795 - root_mean_squared_error: 1.6061
# 18/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9414 - root_mean_squared_error: 1.3918
# 38/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9284 - root_mean_squared_error: 1.3879
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9065 - root_mean_squared_error: 1.3800 - val_loss: 1.6478 - val_root_mean_squared_error: 1.2837
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.4022 - root_mean_squared_error: 1.1842
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6485 - root_mean_squared_error: 1.2829
#
# 100%|██████████| 4/4 [01:25<00:00, 21.26s/trial, best loss: 0.7309171557426453]
# Best parameters: {'lr': np.float64(0.0168248993510428), 'momentum': np.float64(0.8550819377401098)}
# Best eval rmse: 0.7309171557426453

# %%
## Inferencing

from mlflow.models import validate_serving_input

model_uri = 'runs:/9e0b52639ab44e6a864f5bd2f460fe42/model'

# The logged model does not contain an input_example.
# Manually generate a serving payload to verify your model prior to deployment.
from mlflow.models import convert_input_example_to_serving_input

# Define INPUT_EXAMPLE via assignment with your own input example to the model
# A valid input example is a data instance suitable for pyfunc prediction
serving_payload = convert_input_example_to_serving_input(test_x)

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)

# %%
# Load model as a PyFuncModel.
model_uri = 'runs:/9e0b52639ab44e6a864f5bd2f460fe42/model'
loaded_model = mlflow.pyfunc.load_model(model_uri)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(test_x))

# %%
## Register in the model registry
mlflow.register_model(model_uri,"wine-quality")
